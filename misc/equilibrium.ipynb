# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt

# %%
def c_FeSCN2p(Y, Z, B1, I=None, z_rhs=(2,), z_lhs=(3,-1)):
    if I is None:
        I = Z + 6*Y
    if I is not 0:
        A = 0.509
        z_factor = sum([z**2 for z in z_rhs] + [-z**2 for z in z_lhs])
        B1 = B1 * 10**(A*z_factor*I**0.5)
    c0 = (Y+Z+1.0/B1)
    return c0/2 - (c0**2/4 - Y*Z)**0.5

# %%
def plot(Z, I=None, excess=None):
    if excess is None:
        excess = np.linspace(1, 20)
    Y = Z*excess
    plt.plot(Y/Z, c_FeSCN2p(Y, Z, 116, I)/Z, label='Z = {} mM'.format(Z*1000))
plot(1e-3, I=0)
plot(2e-3, I=0)
plot(4e-3, I=0)
plt.title('Neglecting ionic strength')
plt.xlabel('Y / Z')
plt.ylabel('x / Z')
_ = plt.legend(loc='best')

# %%
plot(1e-3)
plot(2e-3)
plot(4e-3)
plt.title('Debye-Huckel limiting law')
plt.xlabel('Y / Z')
plt.ylabel('x / Z')
_ = plt.legend(loc='best')

# %%
a_Fe3p = 0.9  # nm
a_SCNm = 0.35  # nm
a_FeSCN2p = 0.6  # nm  - assumed same as Fe2+

# %%
def dh_A(T, eps=None):
    if eps is None:
        eps = 78.4
    return 1.82e6*(eps*T)**(-3./2)

def dhe_B(T, eps=None):
    if eps is None:
        eps = 78.4
    return 50.3*(eps*T)**(-1./2)

def dhe_log10_gamma(I, z, a, A, B):
    # Debye-Hückel extended
    return -A*z**2*I**0.5/(1+B*a*I**0.5)

# %%
def eps_water(T=298.15, P=1.0):
    """
    Permitivity of water according to the parametrization by Bradley and Pitzer
    (empirical parametrization)
    
    Parameters
    ----------
    T: float
        Temperature in Kelvin
    P: float
        Pressure in bar
        
    References
    ----------
    - Bradley, D.J.; Pitzer, K.S. `Thermodynamics of electrolytes. 12. Dielectric
        properties of water and Debye--Hueckel parameters to 350/sup 0/C and 1 kbar`,
        J. Phys. Chem.; Journal Volume 83 (12) (1979), pp. 1599-1603
        http://pubs.acs.org/doi/abs/10.1021/j100475a009
        DOI: 10.1021/j100475a009
    """
    from math import exp
    from math import log as ln
    U = [0,  3.4279e2, -5.0866e-3, 9.4690e-7, -2.0525, 3.1159e3, 
        -1.8289e2, -8.0325e3, 4.2142e6, 2.1417]
    B  = U[7] + U[8]/T + U[9]*T
    C  = U[4] + U[5]/(U[6]+T)
    eps1000 = U[1]*exp(U[2]*T+U[3]*T**2)
    return eps1000 + C*ln((B+P)/(B+1000.0))

# %%
def dhe_activity_product(I, z_lhs, z_rhs, a_lhs, a_rhs, T, eps=None):
    A = dh_A(T, eps)
    B = dhe_B(T, eps)
    tot = 0
    for z, a in zip(z_lhs, a_lhs):
        tot -= dhe_log10_gamma(I, z, a, A, B)
    for z, a in zip(z_rhs, a_rhs):
        tot += dhe_log10_gamma(I, z, a, A, B)    
    return 10**tot

# %%
eps_water(298.15)
# Out:
# 78.38436874203077

# %%
I = 0.2
dhe_activity_product(I, (3, -1), (2,), (a_Fe3p, a_SCNm), (a_FeSCN2p,), 298.15, eps=eps_water(298.15))
# Out:
# 15.484715947294697

# %%
def ionic_strength(molalities, charges):
    tot = 0
    for b, z in zip(molalities, charges):
        tot += b*z**2
    return 0.5*tot

# %%
def equilibrium_quotient(c_lhs, c_rhs):
    tot = 1
    for c in c_lhs:
        tot /= c
    for c in c_rhs:
        tot *= c
    return tot

# %%
def equilibrium_residual(chi, K, stoich, c0, z, a, T, rho=1.0):
    c = c0 + chi*stoich
    c_lhs, c_rhs, z_lhs, z_rhs, a_lhs, a_rhs = [], [], [], [], [], []
    for i, coeff in enumerate(stoich):
        if coeff > 0:
            c_rhs.append(c[i])
            z_rhs.append(z[i])
            a_rhs.append(a[i])
        elif coeff < 0:
            c_lhs.append(c[i])
            z_lhs.append(z[i])
            a_rhs.append(a[i])
    Q = equilibrium_quotient(c_lhs, c_rhs)
    eps = eps_water(T)
    I = ionic_strength(c/rho, z)
    ap = dhe_activity_product(I, z_lhs, z_rhs, a_lhs, a_rhs, T, eps)
    return K - ap*Q

# %%
K = 10**2.016
stoich = (1, -1, -1)  # FeSCN2+, Fe3+, SCN-
z = (2, 3, -1)
a = (a_FeSCN2p, a_Fe3p, a_SCNm)
c0 = (0.0, 4e-3, 2e-3)
T = 298.15

# %%
np.seterr(all='raise')
equilibrium_residual(0e-3, K, np.array(stoich), np.array(c0), z, a, T)
# Out:
# 103.75284158180126

# %%
chi = np.linspace(0,1.5e-3)
plt.plot(chi, [equilibrium_residual(x, K, np.array(stoich), np.array(c0), z, a, T) for x in chi])

# %%
def get_chi_interval(stoich, c0):
    limits = c0/stoich
    if np.any(limits < 0):
        upper = -np.max(limits[np.argwhere(limits < 0)])
    else:
        upper = 0
    if np.any(limits > 0):
        lower = -np.min(limits[np.argwhere(limits > 0)])
    else:
        lower = 0
    if lower is 0 and upper is 0:
        raise ValueError("0-interval")
    else:
        return lower, upper

# %%
get_chi_interval(np.array(stoich), np.array(c0))
# Out:
# (0, 0.002)

# %%
from scipy.optimize import brentq

def solve_equilibrium(K, stoich, c0, z, a, T):
    lower, upper = get_chi_interval(np.array(stoich), np.array(c0))
    chi = brentq(equilibrium_residual, lower+1e-16, upper-1e-16, (K, np.array(stoich), np.array(c0), z, a, T))
    return np.array(c0) + chi*np.array(stoich)

# %%
c0 = (1e-24, 4e-3, 2e-3)
c0
# Out:
# (1e-24, 0.004, 0.002)

# %%
solve_equilibrium(K, stoich, c0, z, a, T)
# Out:
# array([ 0.00075636,  0.00324364,  0.00124364])

# %%
excess = np.linspace(1, 20)
scn0 = 2e-3
c = []
for e in excess:
    c0 = (0, e*scn0, scn0)
    c.append(solve_equilibrium(K, stoich, c0, z, a, T))
c = np.array(c)
plt.plot(excess, c[:, 0]/scn0, label='extended debye-huckel')
plot(scn0, I=0)
plot(scn0)
plt.legend(loc='best')
_ = plt.title('Predicted yield for different ionic strength treatments')
