# %% [markdown]
# reaktantlösningar:
#
# I)
# 3 mM KSCN
# 33 mM NaClO4
# 50 mM HClO4
#
# II)
# 6 mM Fe(ClO4)3
# 50 mM HClO4
#
# a, b, c, d:
# +0, +20, +40, +60 mM NaClO4 till båda lösningarna

# %%
from __future__ import division
import os
import collections

import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

from aqchem.kinetics.integrated import pseudo_irrev, pseudo_rev, binary_irrev, binary_rev

# %matplotlib inline

# %%
def partial(fun, *args, **kwargs):
    """ functools.partial does not seem to preserve name attribute """
    from functools import partial as _partial
    f = _partial(fun, *args, **kwargs)
    f.name = fun.name
    return f

# %%
# !ls spec_data2/*
# !echo "\n\nspec_data2/a/16.5:"
# !ls spec_data2/a/16.5
# Out:
# spec_data2/a:
# 16.5  18.5  20.5  22.5	24.5
#
# spec_data2/b:
# 16.5  18.5  20.5  22.5	24.5
#
# spec_data2/c:
# 16.5  18.5  20.5  22.5	24.5
#
# spec_data2/d:
# 16.5  18.5  20.5  22.5	24.5
# spec_data2/a/16.5:
# 1.txt  2.txt  3.txt  4.txt  5.txt  6.txt  7.txt

# %%
deciCs = 165, 185, 205, 225, 245
tempKs = 0.1*np.array(deciCs) + 273.15
Itoks = b'abcd'
limiting_C = 3e-3
excess_C = 6e-3
Ibase = 86e-3
beta = 10**2.065
eps_l = 5148
nreplicates = 7
nfuncs = 4
ionic_strengths = Ibase + 1e-3*np.array([0, 20, 40, 60])

# %%
funcs = collections.OrderedDict([
    ('pseudo_irrev', partial(pseudo_irrev, excess_C=excess_C, limiting_C=limiting_C, eps_l=eps_l)),
    ('pseudo_rev', partial(pseudo_rev, excess_C=excess_C, limiting_C=limiting_C, eps_l=eps_l, beta=beta)),
    ('binary_irrev', partial(binary_irrev, excess_C=excess_C, limiting_C=limiting_C, eps_l=eps_l)),
    ('binary_rev', partial(binary_rev, excess_C=excess_C, limiting_C=limiting_C, eps_l=eps_l, beta=beta))
])

# %%
data = {}
def commadecimal2float(s):
    return float(s.replace(',', '.'))
for Itok in Itoks:
    for deciC in deciCs:
        for idx in range(7):
            arr = np.loadtxt(
                os.path.join('spec_data2', Itok, str(deciC//10) + '.' + str(deciC % 10) + '/' + str(idx+1) + '.txt'),
                converters=dict(zip(range(2), [commadecimal2float]*2)))
            arr[:, 0] *= 1e-3  # ms -> s
            data[Itok, deciC, idx] = arr
len(data.keys())
data['a', 165, 0].shape, data['a', 165, 0].dtype, data['a', 165, 0][-1, :]
# Out:
# ((282, 2), dtype('float64'), array([ 3.01  ,  0.3548]))

# %%
fitparams = collections.defaultdict(dict)
for idx0, deciC in enumerate(deciCs):
    for idx1, Itok in enumerate(Itoks):
        for idx in range(nreplicates):
            arr = data[Itok, deciC, idx]
            for funckey, func in funcs.items():
                fitparams[Itok, deciC, idx][funckey] = curve_fit(func, arr[:, 0], arr[:, 1], [250, 0.1, -0.05])

# %%
def plot_fits(funckey):
    c = 'rgbcmyk'
    plt.figure(figsize=(20,25))
    for idx0, deciC in enumerate(deciCs):
        for idx1, Itok in enumerate(Itoks):
            plt.subplot(5, 4, 4*idx0 + idx1 + 1)
            plt.title("{} {}".format(deciC, Itok))
            for idx in range(nreplicates):
                tpl = Itok, deciC, idx
                arr = data[tpl]
                plt.plot(arr[:, 0], arr[:, 1], alpha=0.3, c=c[idx])
                
                popt, pcov = fitparams[tpl][funckey]
                fmtstr = '$k_f = {0:.1f} \pm {1:.1f}$ $M^{{-1}} s^{{-1}}$'
                lbl = fmtstr.format(popt[0], pcov[0, 0]**0.5)
                plt.plot(arr[:, 0], funcs[funckey](arr[:, 0], *popt), alpha=0.3, label=lbl, c=c[idx])
                
            plt.legend(loc='best')
            plt.ylim((0, 0.40))

# %%
plot_fits('pseudo_irrev')

# %%
plot_fits('pseudo_rev')

# %%
plot_fits('binary_irrev')

# %%
plot_fits('binary_rev')

# %%
pooled_fits = dict()
rel_err = collections.defaultdict(float)
for idx0, deciC in enumerate(deciCs):
    for idx1, Itok in enumerate(Itoks):
        for funckey in funcs.keys():
            weighted_sum = 0.0
            sum_of_weights = 0.0
            for idx in range(nreplicates):
                popt, pcov = fitparams[Itok, deciC, idx][funckey]
                weighted_sum += popt[0]/pcov[0, 0]
                sum_of_weights += 1/pcov[0, 0]
            pooled_fits[Itok, deciC, funckey] = (weighted_sum/sum_of_weights, 1/sum_of_weights)
            rel_err[funckey] += 1/weighted_sum
pooled_fits
rel_err.items()
# Out:
# [('binary_irrev', 0.46727586136003296),
#  ('binary_rev', 0.074737865018758939),
#  ('pseudo_rev', 0.080172045059991356),
#  ('pseudo_irrev', 0.19521841416607727)]

# %%
chosen_funckey = 'binary_rev'
kf = np.empty((len(Itoks), len(deciCs), 2))
for idxI, Itok in enumerate(Itoks):
    for idxT, deciC in enumerate(deciCs):
        kf[idxI, idxT, :] = pooled_fits[Itok, deciC, chosen_funckey]
logkf = np.log(kf[:, :, 0])
dlogkf = (np.log(kf[:, :, 0] + kf[:, :, 1]**0.5) - np.log(kf[:, :, 0] - kf[:, :, 1]**0.5))/2

# %%
plt.figure(figsize=(18,5))
for Iidx, Itok in enumerate(Itoks):
    plt.subplot(1, 4, Iidx + 1)
    popt, pcov = np.polyfit(1/tempKs, logkf[Iidx, :], 1, cov=True)
    plt.errorbar(1/tempKs, logkf[Iidx, :], dlogkf[Iidx, :], marker='.', ls='None')
    lbl = '{0:.1f} $\pm$ {1:.1f} kJ/mol'.format(popt[0]*-8.314511e-3, pcov[0,0]**0.5 * 8.314511e-3)
    plt.plot(1/tempKs, np.polyval(popt, 1/tempKs), label=lbl)
    plt.legend(loc='best')

# %%
plt.figure(figsize=(18,5))
sqrtI = np.sqrt(ionic_strengths)
k0 = np.empty(len(deciCs))
for Tidx, deciC in enumerate(deciCs):
    plt.subplot(1, 5, Tidx + 1)
    popt, pcov = np.polyfit(sqrtI, logkf[:, Tidx], 1, cov=True)
    k0[Tidx] = np.exp(popt[1])
    plt.errorbar(sqrtI, logkf[:, Tidx], dlogkf[:, Tidx], marker='.', ls='None')
    lbl = '$k^\circ={0:.1f}$ $M^{{-1}}s^{{-1}}$'.format(k0[Tidx])
    plt.plot(sqrtI, np.polyval(popt, sqrtI), label=lbl)
    plt.legend(loc='best')
k0
# Out:
# array([ 344.69002514,  377.87719214,  467.37331929,  598.27134593,
#         779.82565863])

# %%
popt, pcov = np.polyfit(1/tempKs, np.log(k0), 1, cov=True)
plt.plot(1/tempKs, np.log(k0), '.')
lbl = '{0:.1f} $\pm$ {1:.1f} kJ/mol'.format(popt[0]*-8.314511e-3, pcov[0,0]**0.5 * 8.314511e-3)
plt.plot(1/tempKs, np.polyval(popt, 1/tempKs), label=lbl)
plt.legend()

# %%
def Arrhenius(T, A, Ea):
    R = 8.314511
    return A*np.exp(-Ea/(R*T))

Tspan = tempKs[-1] - tempKs[0]
Tplot = np.linspace(tempKs[0] - 0.05*Tspan, tempKs[-1] + 0.05*Tspan)
fmtstr = ('$E_a={0:5.1f} \pm {1:5.1f}$ $kJ/mol,$\n$'
    'A=({2:5.1f} \pm {3:5.1f}) \cdot 10^{{16}} M^{{-1}} s^{{-1}}$')
plt.figure(figsize=(14,8))
for fidx, (funckey, func) in enumerate(funcs.items()):
    plt.subplot(2, 2, fidx + 1)
    plt.errorbar(tempKs, kf_val[funckey], kf_err[funckey], marker='.', linestyle='None')
    Ea_guess, A_guess = # log_arr[fidx]
    #plt.plot(T, Arrhenius(T, A_guess, Ea_guess))
    popt, pcov = curve_fit(Arrhenius, T, kf_val[fidx], [A_guess, Ea_guess],  1/kf_err[fidx]**2)
    lbl = fmtstr.format(popt[1]/1e3, pcov[1,1]**0.5/1e3, popt[0]/1e16, pcov[0,0]**0.5/1e16)
    plt.plot(Tplot, Arrhenius(Tplot, *popt), label=lbl)
    plt.xlabel('T / K')
    plt.ylabel('$k_f$ / $M^{-1} \cdot s^{-1}$')
    plt.legend(loc='best')
    plt.title(funcs[func].name)

plt.tight_layout()
